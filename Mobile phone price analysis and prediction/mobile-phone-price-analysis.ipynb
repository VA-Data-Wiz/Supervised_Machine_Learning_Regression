# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_data = pd.read_csv('mobile-phone-price.csv')
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1370 non-null   int64
#  1   Name               1370 non-null   object
#  2   Rating             1370 non-null   float64
#  3   Spec_score         1370 non-null   int64
#  4   No_of_sim          1370 non-null   object
#  5   Ram                1370 non-null   object
#  6   Battery            1370 non-null   object
#  7   Display            1370 non-null   object
#  8   Camera             1370 non-null   object
#  9   External_Memory    1370 non-null   object
#  10  Android_version    927 non-null    object
#  11  Price              1370 non-null   object
#  12  company            1370 non-null   object
#  13  Inbuilt_memory     1351 non-null   object
#  14  fast_charging      1281 non-null   object
#  15  Screen_resolution  1368 non-null   object
# ...

# %%
data = raw_data.drop('Unnamed: 0', axis=1)
data.describe(include='all')
# Out:
#                                       Name       Rating   Spec_score  \
# count                                 1370  1370.000000  1370.000000
# unique                                1334          NaN          NaN
# top     Realme Narzo N55 (6GB RAM + 128GB)          NaN          NaN
# freq                                     3          NaN          NaN
# mean                                   NaN     4.374416    80.234307
# std                                    NaN     0.230176     8.373922
# min                                    NaN     3.750000    42.000000
# 25%                                    NaN     4.150000    75.000000
# 50%                                    NaN     4.400000    82.000000
# 75%                                    NaN     4.550000    86.000000
# max                                    NaN     4.750000    98.000000
#
#                             No_of_sim       Ram            Battery  \
# count                            1370      1370               1370
# ...

# %%
data['Price'] = data['Price'].str.replace(',', '').astype(float)

# %%
data.describe(include='all')
# Out:
#                                       Name       Rating   Spec_score  \
# count                                 1370  1370.000000  1370.000000
# unique                                1334          NaN          NaN
# top     Realme Narzo N55 (6GB RAM + 128GB)          NaN          NaN
# freq                                     3          NaN          NaN
# mean                                   NaN     4.374416    80.234307
# std                                    NaN     0.230176     8.373922
# min                                    NaN     3.750000    42.000000
# 25%                                    NaN     4.150000    75.000000
# 50%                                    NaN     4.400000    82.000000
# 75%                                    NaN     4.550000    86.000000
# max                                    NaN     4.750000    98.000000
#
#                             No_of_sim       Ram            Battery  \
# count                            1370      1370               1370
# ...

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.despine(f)
sns.boxplot(data=data, x='Rating', y='company',palette='rainbow', orient='h')
# Out:
# <Axes: xlabel='Rating', ylabel='company'>

# %%
data['company'] = data['company'].str.lower()
data['company'].value_counts()
# Out:
# company
# vivo        186
# realme      186
# samsung     181
# motorola    127
# poco         94
# xiaomi       90
# honor        88
# oneplus      75
# oppo         65
# huawei       62
# iqoo         58
# tcl          26
# google       23
# asus         21
# lava         19
# itel         15
# nothing      15
# lenovo       14
# tecno        13
# lg            6
# gionee        5
# coolpad       1
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.despine(f)
sns.boxplot(data=data, x='Price', y='company',palette='rainbow', orient='h')
# Out:
# <Axes: xlabel='Price', ylabel='company'>

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.despine(f)
sns.scatterplot(data=data, x='Spec_score', y='Price')
# Out:
# <Axes: xlabel='Spec_score', ylabel='Price'>

# %%
data.Processor_name.value_counts()
# Out:
# Processor_name
# Snapdragon 8+ Gen1    58
# Snapdragon 8 Gen2     55
# Snapdragon 8 Gen3     44
# Snapdragon 695        36
# Snapdragon 680        34
#                       ..
# Dimensity 8000         1
# Dimensity  1100        1
# Dimensity 920          1
# Snapdragon  765G       1
# Helio A25              1
# Name: count, Length: 276, dtype: int64

# %%
data.Processor.value_counts()
# Out:
# Processor
#  Octa Core              1237
#  Octa Core Processor      75
#  Quad Core                11
#  1.6 GHz Processor         3
#  Deca Core                 3
#  2 GHz Processor           2
#  Nine-Cores                2
#  Nine Core                 2
#  Nine Cores                2
#  1.8 GHz Processor         1
#  Deca Core Processor       1
#  1.3 GHz Processor         1
#  2.3 GHz Processor         1
#  128 GB inbuilt            1
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.despine(f)
sns.barplot(data=data, x='Price', y='Processor',palette='rainbow', orient='h')
# Out:
# <Axes: xlabel='Price', ylabel='Processor'>

# %%
data[(data['Price']>=140000) & (data['Spec_score']<=80)]
# Out:
#                     Name  Rating  Spec_score                    No_of_sim  \
# 1052  Motorola Razr 2019    4.25          73  Single Sim, 3G, 4G, VoLTE,
#
#            Ram            Battery     Display        Camera  \
# 1052  6 GB RAM  2510 mAh Battery   6.2 inches  Dual Display
#
#                          External_Memory Android_version     Price   company  \
# 1052  16 MP Rear &amp; 5 MP Front Camera             NaN  149999.0  motorola
#
#        Inbuilt_memory       fast_charging  \
# 1052   128 GB inbuilt   18W Fast Charging
#
#                             Screen_resolution   Processor  Processor_name
# 1052   876 x 2142 px Display with Large Notch   Octa Core  Snapdragon 710

# %%
# droping the 'Motorola Razr 2019' as outlier
data1 = data.drop(index=1052)
f, ax = plt.subplots(figsize=(10,8))
sns.despine(f)
sns.scatterplot(data=data1, x='Spec_score', y='Price')
# Out:
# <Axes: xlabel='Spec_score', ylabel='Price'>

# %%
# let's check the higher priced phone
data.sort_values(by=['Price'], ascending=False).head(10)
# Out:
#                                             Name  Rating  Spec_score  \
# 1279            Huawei Mate 30 RS Porsche Design    4.15          95
# 76                 Samsung Galaxy Z Fold 6 Ultra    4.05          96
# 1287            Huawei Mate 40 RS Porsche Design    4.30          94
# 608            Honor Magic V2 RSR Porsche Design    4.75          93
# 77      Samsung Galaxy Z Fold 5 (12GB RAM + 1TB)    4.45          93
# 78                       Samsung Galaxy Z Fold 6    4.45          92
# 79                       Samsung Galaxy Z Fold 4    4.75          91
# 80    Samsung Galaxy Z Fold 5 (12GB RAM + 512GB)    4.05          93
# 81    Samsung Galaxy Z Fold 4 (12GB RAM + 512GB)    4.35          92
# 82     Samsung Galaxy S24 Ultra (12GB RAM + 1TB)    4.60          96
#
#                                 No_of_sim        Ram            Battery  \
# 1279        Dual Sim, 3G, 4G, 5G, VoLTE,   12 GB RAM  4500 mAh Battery
# ...

# %%
data1.External_Memory.value_counts()
# Out:
# External_Memory
# Memory Card Supported, upto 1 TB                                               233
# Memory Card (Hybrid), upto 1 TB                                                161
# Memory Card Not Supported                                                      142
# Android v13                                                                    107
# Android v12                                                                    104
#                                                                               ...
# 48 MP + 12 MP Dual Rear &amp; 10 MP Front Camera                                 1
# 48 MP + 10.8 MP + 10.8 MP Triple Rear &amp; 9.5 MP + 8 MP Dual Front Camera      1
# 50 MP + 10.8 MP + 10.8 MP Triple Rear &amp; 12 MP + 12 MP Dual Front Camera      1
# Memory Card Supported, upto 32 GB                                                1
# 50 MP + 48 MP + 8 MP Triple Rear &amp; 32 MP Front Camera                        1
# Name: count, Length: 84, dtype: int64

# %%
f, ax = plt.subplots(figsize=(10,20))
sns.despine(f)
sns.barplot(data=data, x='Price', y='External_Memory',palette='rainbow', orient='h')
# Out:
# <Axes: xlabel='Price', ylabel='External_Memory'>

# %%
data1.columns
# Out:
# Index(['Name', 'Rating', 'Spec_score', 'No_of_sim', 'Ram', 'Battery',
#        'Display', 'Camera', 'External_Memory', 'Android_version', 'Price',
#        'company', 'Inbuilt_memory', 'fast_charging', 'Screen_resolution',
#        'Processor', 'Processor_name'],
#       dtype='object')

# %%
data2 = data1.drop(['Name','No_of_sim', 'Camera','External_Memory','Android_version','Screen_resolution','Processor_name'],axis=1)
data2.head()
# Out:
#    Rating  Spec_score       Ram            Battery     Display    Price  \
# 0    4.65          68  4 GB RAM  6000 mAh Battery   6.6 inches   9999.0
# 1    4.20          63  2 GB RAM  4000 mAh Battery   6.4 inches   9990.0
# 2    4.30          75  4 GB RAM  5000 mAh Battery   6.6 inches  11999.0
# 3    4.10          73  4 GB RAM   6000 mAh Battery  6.4 inches  11999.0
# 4    4.10          69  4 GB RAM  5000 mAh Battery   6.5 inches  11999.0
#
#    company   Inbuilt_memory       fast_charging             Processor
# 0  samsung   128 GB inbuilt   25W Fast Charging   Octa Core Processor
# 1  samsung    32 GB inbuilt   15W Fast Charging     1.8 GHz Processor
# 2  samsung    64 GB inbuilt   25W Fast Charging       2 GHz Processor
# 3  samsung    64 GB inbuilt                 NaN             Octa Core
# 4  samsung    64 GB inbuilt   15W Fast Charging             Octa Core

# %%
data2.isnull().sum()
# Out:
# Rating             0
# Spec_score         0
# Ram                0
# Battery            0
# Display            0
# Price              0
# company            0
# Inbuilt_memory    19
# fast_charging     89
# Processor         28
# dtype: int64

# %%
data3 = data2.dropna(axis=0)
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1236 entries, 0 to 1369
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rating          1236 non-null   float64
#  1   Spec_score      1236 non-null   int64
#  2   Ram             1236 non-null   object
#  3   Battery         1236 non-null   object
#  4   Display         1236 non-null   object
#  5   Price           1236 non-null   float64
#  6   company         1236 non-null   object
#  7   Inbuilt_memory  1236 non-null   object
#  8   fast_charging   1236 non-null   object
#  9   Processor       1236 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 106.2+ KB

# %%
data3.Ram.value_counts()
# Out:
# Ram
# 8 GB RAM     517
# 12 GB RAM    241
# 4 GB RAM     216
# 6 GB RAM     195
# 16 GB RAM     39
# 3 GB RAM      16
# 2 GB RAM       6
# 18 GB RAM      4
# 24 GB RAM      2
# Name: count, dtype: int64

# %%
data4 = data3.copy()
data4['Ram'] = data4['Ram'].apply(lambda x : int(x.split(' ')[0]))
data4.head()
# Out:
#    Rating  Spec_score  Ram            Battery     Display    Price  company  \
# 0    4.65          68    4  6000 mAh Battery   6.6 inches   9999.0  samsung
# 1    4.20          63    2  4000 mAh Battery   6.4 inches   9990.0  samsung
# 2    4.30          75    4  5000 mAh Battery   6.6 inches  11999.0  samsung
# 4    4.10          69    4  5000 mAh Battery   6.5 inches  11999.0  samsung
# 5    4.40          75    6  5000 mAh Battery   6.5 inches  11990.0  samsung
#
#     Inbuilt_memory       fast_charging             Processor
# 0   128 GB inbuilt   25W Fast Charging   Octa Core Processor
# 1    32 GB inbuilt   15W Fast Charging     1.8 GHz Processor
# 2    64 GB inbuilt   25W Fast Charging       2 GHz Processor
# 4    64 GB inbuilt   15W Fast Charging             Octa Core
# 5   128 GB inbuilt   15W Fast Charging             Octa Core

# %%
f, ax = plt.subplots(figsize=(10,5))
sns.despine(f)
sns.barplot(data=data4, x='Price', y='Ram',palette='rainbow', orient='h')
# Out:
# <Axes: xlabel='Price', ylabel='Ram'>

# %%
data4.Battery.value_counts()
# Out:
# Battery
# 5000 mAh Battery     677
# 4500 mAh Battery     111
# 6000 mAh Battery      96
# 4000 mAh Battery      35
# 4800 mAh Battery      32
#                     ...
# 4385 mAh Battery       1
# 4620 mAh Battery       1
# 3400 mAh Battery       1
# 5065 mAh Battery       1
# 4320 mAh Battery       1
# Name: count, Length: 68, dtype: int64

# %%
data4['Battery'] = data4['Battery'].apply(lambda x: int(x.split(' ')[0]))
data4.head(5)
# Out:
#    Rating  Spec_score  Ram  Battery     Display    Price  company  \
# 0    4.65          68    4     6000  6.6 inches   9999.0  samsung
# 1    4.20          63    2     4000  6.4 inches   9990.0  samsung
# 2    4.30          75    4     5000  6.6 inches  11999.0  samsung
# 4    4.10          69    4     5000  6.5 inches  11999.0  samsung
# 5    4.40          75    6     5000  6.5 inches  11990.0  samsung
#
#     Inbuilt_memory       fast_charging             Processor
# 0   128 GB inbuilt   25W Fast Charging   Octa Core Processor
# 1    32 GB inbuilt   15W Fast Charging     1.8 GHz Processor
# 2    64 GB inbuilt   25W Fast Charging       2 GHz Processor
# 4    64 GB inbuilt   15W Fast Charging             Octa Core
# 5   128 GB inbuilt   15W Fast Charging             Octa Core

# %%
data4.Display.value_counts()
# Out:
# Display
# 6.7 inches     151
# 6.67 inches    142
# 6.78 inches    137
# 6.5 inches      93
# 6.6 inches      88
#               ...
# 6.34 inches      1
# 5.7 inches       1
# 5.6 inches       1
# 12.1 inches      1
# 10 inches        1
# Name: count, Length: 80, dtype: int64

# %%
data4['Display'] = data4['Display'].apply(lambda x: float(x.split(' ')[0]))
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1236 entries, 0 to 1369
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rating          1236 non-null   float64
#  1   Spec_score      1236 non-null   int64
#  2   Ram             1236 non-null   int64
#  3   Battery         1236 non-null   int64
#  4   Display         1236 non-null   float64
#  5   Price           1236 non-null   float64
#  6   company         1236 non-null   object
#  7   Inbuilt_memory  1236 non-null   object
#  8   fast_charging   1236 non-null   object
#  9   Processor       1236 non-null   object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 106.2+ KB

# %%
data4.Inbuilt_memory.value_counts()
# Out:
# Inbuilt_memory
#  128 GB inbuilt    609
#  256 GB inbuilt    397
#  64 GB inbuilt     150
#  512 GB inbuilt     57
#  32 GB inbuilt      17
#  1 TB inbuilt        5
#  258 GB inbuilt      1
# Name: count, dtype: int64

# %%
data5 = data4.copy()
data5['Inbuilt_memory'] = data5['Inbuilt_memory'].apply(lambda x: int(x.split(' ')[1]))
data5.head()
# here x.split cannot take [0] index.
# maybe there is a space at [0] position.
# so [1] position will suffice for this operation
# Out:
#    Rating  Spec_score  Ram  Battery  Display    Price  company  \
# 0    4.65          68    4     6000      6.6   9999.0  samsung
# 1    4.20          63    2     4000      6.4   9990.0  samsung
# 2    4.30          75    4     5000      6.6  11999.0  samsung
# 4    4.10          69    4     5000      6.5  11999.0  samsung
# 5    4.40          75    6     5000      6.5  11990.0  samsung
#
#    Inbuilt_memory       fast_charging             Processor
# 0             128   25W Fast Charging   Octa Core Processor
# 1              32   15W Fast Charging     1.8 GHz Processor
# 2              64   25W Fast Charging       2 GHz Processor
# 4              64   15W Fast Charging             Octa Core
# 5             128   15W Fast Charging             Octa Core

# %%
data5['Inbuilt_memory'] = data5['Inbuilt_memory'].replace(to_replace=1, value=1024)
data5.Inbuilt_memory.value_counts()
# Out:
# Inbuilt_memory
# 128     609
# 256     397
# 64      150
# 512      57
# 32       17
# 1024      5
# 258       1
# Name: count, dtype: int64

# %%
data5.fast_charging.value_counts()
# Out:
# fast_charging
#  18W Fast Charging      155
#  33W Fast Charging      141
#  67W Fast Charging      100
#  25W Fast Charging       94
#  80W Fast Charging       76
#  100W Fast Charging      62
#  15W Fast Charging       61
#  120W Fast Charging      60
#  44W Fast Charging       60
#  66W Fast Charging       59
#  45W Fast Charging       58
#  65W Fast Charging       50
#  30W Fast Charging       43
#  Fast Charging           39
#  10W Fast Charging       38
#  150W Fast Charging      23
#  68W Fast Charging       20
#  40W Fast Charging       15
#  22.5W Fast Charging     15
#  35W Fast Charging       14
#  125W Fast Charging      12
#  20W Fast Charging       11
#  200W Fast Charging       7
#  240W Fast Charging       3
#  55W Fast Charging        3
#  90W Fast Charging        3
#  50W Fast Charging        2
#  250W Fast Charging       2
#  27W Fast Charging        2
#  88W Fast Charging        2
#  135W Fast Charging       1
#  70W Fast Charging        1
# ...

# %%
data5['fast_charging'] = data5['fast_charging'].apply(lambda x: str(x.split(' ')[1]))
data5.head(10)
# Out:
#     Rating  Spec_score  Ram  Battery  Display    Price  company  \
# 0     4.65          68    4     6000      6.6   9999.0  samsung
# 1     4.20          63    2     4000      6.4   9990.0  samsung
# 2     4.30          75    4     5000      6.6  11999.0  samsung
# 4     4.10          69    4     5000      6.5  11999.0  samsung
# 5     4.40          75    6     5000      6.5  11990.0  samsung
# 6     4.10          76    4     6000      6.4  11990.0  samsung
# 7     4.10          71    4     5000      6.5  11990.0  samsung
# 8     4.05          75    4     5000      6.6  11599.0  samsung
# 9     4.50          75    6     6000      6.6  12298.0  samsung
# 10    4.25          85    8     6000      6.5  14999.0  samsung
#
#     Inbuilt_memory fast_charging             Processor
# 0              128           25W   Octa Core Processor
# 1               32           15W     1.8 GHz Processor
# 2               64           25W       2 GHz Processor
# ...

# %%
data5.fast_charging.value_counts()
# Out:
# fast_charging
# 18W      155
# 33W      141
# 67W      100
# 25W       94
# 80W       76
# 100W      62
# 15W       61
# 120W      60
# 44W       60
# 66W       59
# 45W       58
# 65W       50
# 30W       43
# Fast      39
# 10W       38
# 150W      23
# 68W       20
# 40W       15
# 22.5W     15
# 35W       14
# 125W      12
# 20W       11
# 200W       7
# 240W       3
# 55W        3
# 90W        3
# 50W        2
# 250W       2
# 27W        2
# 88W        2
# 135W       1
# 70W        1
# 60W        1
# 68.2W      1
# 08W        1
# 7.5W       1
# Name: count, dtype: int64

# %%
data5[data5['fast_charging']=='Fast']
# data[(data['Price']>=140000) & (data['Spec_score']<=80)]
# Out:
#       Rating  Spec_score  Ram  Battery  Display     Price   company  \
# 32      4.35          88    8     4500     6.50   29999.0   samsung
# 43      4.45          78    6     3400     6.40   39990.0   samsung
# 58      4.10          80    8     5000     6.70   47990.0   samsung
# 65      4.00          89   12     4500     6.10   59999.0   samsung
# 70      4.35          88    8     4500     6.40   64999.0   samsung
# 71      4.20          75    6     3300     6.30   65690.0   samsung
# 75      4.40          76    6     3500     6.20   70000.0   samsung
# 171     4.30          85    8     4500     6.50   42999.0      vivo
# 172     4.20          85    8     4500     6.50   49999.0      vivo
# 301     4.50          80    6     5000     6.55   29990.0    realme
# 319     4.30          84    8     5000     6.62   34990.0    realme
# 436     4.75          83    8     5000     6.62   37990.0      iqoo
# 612     4.20          88    8     4000     8.00  104999.0     honor
# ...

# %%
data6 = data5.copy()
# data5['fast_charging'] = data5['fast_charging'].apply(lambda x: str(x.split(' ')[1]))
# data6['fast_charging'] = data6['fast_charging'].apply(lambda x: int(x.str.extract('(\d+)')))
## data6[data6.fast_charging.str.extract('(^\d*)')
data6 = data6.assign(fast_charging = lambda x: x['fast_charging'].str.extract('(\d+)'))

# %%
data6.head()
# Out:
#    Rating  Spec_score  Ram  Battery  Display    Price  company  \
# 0    4.65          68    4     6000      6.6   9999.0  samsung
# 1    4.20          63    2     4000      6.4   9990.0  samsung
# 2    4.30          75    4     5000      6.6  11999.0  samsung
# 4    4.10          69    4     5000      6.5  11999.0  samsung
# 5    4.40          75    6     5000      6.5  11990.0  samsung
#
#    Inbuilt_memory fast_charging             Processor
# 0             128            25   Octa Core Processor
# 1              32            15     1.8 GHz Processor
# 2              64            25       2 GHz Processor
# 4              64            15             Octa Core
# 5             128            15             Octa Core

# %%
data6['fast_charging'].fillna('0',inplace=True)
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1236 entries, 0 to 1369
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rating          1236 non-null   float64
#  1   Spec_score      1236 non-null   int64
#  2   Ram             1236 non-null   int64
#  3   Battery         1236 non-null   int64
#  4   Display         1236 non-null   float64
#  5   Price           1236 non-null   float64
#  6   company         1236 non-null   object
#  7   Inbuilt_memory  1236 non-null   int64
#  8   fast_charging   1236 non-null   object
#  9   Processor       1236 non-null   object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 106.2+ KB

# %%
data6['fast_charging'] = data6['fast_charging'].astype(int)
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1236 entries, 0 to 1369
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rating          1236 non-null   float64
#  1   Spec_score      1236 non-null   int64
#  2   Ram             1236 non-null   int64
#  3   Battery         1236 non-null   int64
#  4   Display         1236 non-null   float64
#  5   Price           1236 non-null   float64
#  6   company         1236 non-null   object
#  7   Inbuilt_memory  1236 non-null   int64
#  8   fast_charging   1236 non-null   int32
#  9   Processor       1236 non-null   object
# dtypes: float64(3), int32(1), int64(4), object(2)
# memory usage: 101.4+ KB

# %%
data7 = data6.copy()
data7 = data6.replace(to_replace=0, value= data6.fast_charging.mean())
data7.fast_charging.value_counts()
# Out:
# fast_charging
# 18.000000     155
# 33.000000     141
# 67.000000     100
# 25.000000      94
# 80.000000      76
# 100.000000     62
# 15.000000      61
# 120.000000     60
# 44.000000      60
# 66.000000      59
# 45.000000      58
# 65.000000      50
# 30.000000      43
# 50.675566      39
# 10.000000      38
# 150.000000     23
# 68.000000      21
# 40.000000      15
# 22.000000      15
# 35.000000      14
# 125.000000     12
# 20.000000      11
# 200.000000      7
# 55.000000       3
# 240.000000      3
# 90.000000       3
# 250.000000      2
# 27.000000       2
# 50.000000       2
# 88.000000       2
# 60.000000       1
# 8.000000        1
# 135.000000      1
# 70.000000       1
# 7.000000        1
# Name: count, dtype: int64

# %%
data7.Processor.value_counts()
# Out:
# Processor
#  Octa Core              1146
#  Octa Core Processor      74
#  Deca Core                 3
#  2 GHz Processor           2
#  Quad Core                 2
#  Nine-Cores                2
#  Nine Core                 2
#  Nine Cores                2
#  1.8 GHz Processor         1
#  Deca Core Processor       1
#  2.3 GHz Processor         1
# Name: count, dtype: int64

# %%
data8 = data7.copy()
data8['Processor'] = data8['Processor'].apply(lambda x: str(x.split(' ')[1]))
data8['Processor'] = data8['Processor'].apply(lambda x: str(x.split('-')[0]))
data8.Processor.value_counts()
# Out:
# Processor
# Octa    1220
# Nine       6
# Deca       4
# 2          2
# Quad       2
# 1.8        1
# 2.3        1
# Name: count, dtype: int64

# %%
data8.describe(include='all')
# Out:
#              Rating   Spec_score          Ram       Battery      Display  \
# count   1236.000000  1236.000000  1236.000000   1236.000000  1236.000000
# unique          NaN          NaN          NaN           NaN          NaN
# top             NaN          NaN          NaN           NaN          NaN
# freq            NaN          NaN          NaN           NaN          NaN
# mean       4.375971    81.493528     7.982201   4946.984628     6.681351
# std        0.228747     7.297104     3.132125    515.287597     0.322024
# min        3.900000    53.000000     2.000000   2800.000000     5.000000
# 25%        4.200000    76.000000     6.000000   4800.000000     6.560000
# 50%        4.400000    83.000000     8.000000   5000.000000     6.670000
# 75%        4.550000    87.000000     8.000000   5000.000000     6.742500
# max        4.750000    98.000000    24.000000  10500.000000    12.100000
#
#                 Price company  Inbuilt_memory  fast_charging Processor
# ...

# %%
preprocessed_data = data8.to_csv('cleaned-mobile-phone-price.csv', index=False)
print('preprocessed_data is exported as csv')
# Out:
# preprocessed_data is exported as csv

# %%
# Let's transform 'Price' with a log transformation
log_price = np.log(data8['Price'])

# Then we add it to our data frame
data8['log_price'] = log_price
data8
# Out:
#       Rating  Spec_score  Ram  Battery  Display     Price  company  \
# 0       4.65          68    4     6000      6.6    9999.0  samsung
# 1       4.20          63    2     4000      6.4    9990.0  samsung
# 2       4.30          75    4     5000      6.6   11999.0  samsung
# 4       4.10          69    4     5000      6.5   11999.0  samsung
# 5       4.40          75    6     5000      6.5   11990.0  samsung
# ...      ...         ...  ...      ...      ...       ...      ...
# 1365    4.05          75    4     5000      6.6   18999.0      tcl
# 1366    4.10          80    8     5000      6.8   24990.0      tcl
# 1367    4.00          80    6     5000      6.6   23990.0      tcl
# 1368    4.50          79    6     5000      6.6   22499.0      tcl
# 1369    4.65          93   12     4600     10.0  119990.0      tcl
#
#       Inbuilt_memory  fast_charging Processor  log_price
# 0                128           25.0      Octa   9.210240
# ...

# %%
f, axs = plt.subplots(ncols=2, figsize=(15,5))
sns.despine(f)
sns.scatterplot(data=data8, x='Spec_score', y='Price', ax=axs[0])
sns.scatterplot(data=data8, x='Spec_score', y='log_price', ax=axs[1])
# Out:
# <Axes: xlabel='Spec_score', ylabel='log_price'>

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

obj_col = data8.select_dtypes(include='object').columns

for col in obj_col:
    data8[col] = data8[col].str.lower()
    
for col in obj_col:
    data8[col] = le.fit_transform(data8[col])

# %%
x = data8.drop(['Price','log_price'], axis=1)
y = data8['Price']
y2 = data8['log_price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=365)
x_train, x_test, y2_train, y2_test = train_test_split(x, y2, test_size=0.2, random_state=365)

# %%
reg1 = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg1.fit(x_train, x_test, y_train, y_test)
# Out:
#  74%|███████▍  | 31/42 [00:01<00:00, 19.08it/s]
# QuantileRegressor model failed to execute
# Solver interior-point is not anymore available in SciPy >= 1.11.0.
# 100%|██████████| 42/42 [00:02<00:00, 15.32it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000594 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 213
# [LightGBM] [Info] Number of data points in the train set: 988, number of used features: 8
# [LightGBM] [Info] Start training from score 34543.106275

# %%
print(models)
# Out:
#                                Adjusted R-Squared  R-Squared     RMSE  \
# Model
# GradientBoostingRegressor                    0.86       0.86 10830.87
# RandomForestRegressor                        0.85       0.86 11082.68
# BaggingRegressor                             0.85       0.85 11285.75
# XGBRegressor                                 0.85       0.85 11296.23
# ExtraTreesRegressor                          0.83       0.83 11959.31
# LGBMRegressor                                0.81       0.82 12511.90
# HistGradientBoostingRegressor                0.80       0.81 12769.23
# DecisionTreeRegressor                        0.72       0.73 15259.90
# KNeighborsRegressor                          0.70       0.71 15829.89
# ExtraTreeRegressor                           0.62       0.64 17658.38
# RidgeCV                                      0.62       0.63 17812.77
# BayesianRidge                                0.62       0.63 17816.95
# ...

# %%
reg2 = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = reg2.fit(x_train, x_test, y2_train, y2_test)
print(models)
# Out:
# 100%|██████████| 42/42 [00:02<00:00, 14.89it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 213
# [LightGBM] [Info] Number of data points in the train set: 988, number of used features: 8
# [LightGBM] [Info] Start training from score 10.148365
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.88       0.88  0.26        0.11
# RandomForestRegressor                        0.87       0.88  0.27        0.41
# LGBMRegressor                                0.87       0.87  0.27        0.09
# BaggingRegressor                             0.87       0.87  0.27        0.05
# HistGradientBoostingRegressor                0.87       0.87  0.27        0.46
# ExtraTreesRegressor                          0.86       0.86  0.28        0.28
# ...

# %%
data8.head()
# Out:
#    Rating  Spec_score  Ram  Battery  Display    Price  company  \
# 0    4.65          68    4     6000     6.60  9999.00       17
# 1    4.20          63    2     4000     6.40  9990.00       17
# 2    4.30          75    4     5000     6.60 11999.00       17
# 4    4.10          69    4     5000     6.50 11999.00       17
# 5    4.40          75    6     5000     6.50 11990.00       17
#
#    Inbuilt_memory  fast_charging  Processor  log_price
# 0             128          25.00          5       9.21
# 1              32          15.00          0       9.21
# 2              64          25.00          1       9.39
# 4              64          15.00          5       9.39
# 5             128          15.00          5       9.39

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# we will take only the numercial variables
variables = data8.drop(['Price','company','Display','Battery','Rating','Ram','Processor','log_price'], axis=1)
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["Features"] = variables.columns
vif
# after tweeking different features we will initially make linear model with three features.
# 'spec_score' has collinearity with 'Rating', 'Ram', 'Display'
# Out:
#    VIF        Features
# 0 5.24      Spec_score
# 1 4.63  Inbuilt_memory
# 2 3.83   fast_charging

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
lreg = LinearRegression()
# Creating a scaler object
scaler = StandardScaler()


inputs = data8[['Spec_score','Inbuilt_memory','fast_charging','company','Processor']]
targets = data8['log_price']
scaler.fit(inputs)
inputs_scl = scaler.transform(inputs)

# %%
lx_train, lx_test, ly_train, ly_test = train_test_split(inputs, targets, test_size=0.2, random_state=365)
lreg.fit(lx_train, ly_train)
print('Waights:', lreg.coef_)
print('Bias:', lreg.intercept_)
print('R-squared:', lreg.score(lx_train,ly_train))
# Out:
# Waights: [ 0.06661248  0.00114844  0.00195743 -0.01564539 -0.15195082]
# Bias: 5.3830089545635476
# R-squared: 0.7261759477831525

# %%
inputs2 = data8.drop(['Price','log_price'], axis=1)
targets2 = data8['log_price']

lx2_train, lx2_test, ly2_train, ly2_test = train_test_split(inputs2, targets2, test_size=0.2, random_state=365)

l2reg = LinearRegression()
l2reg.fit(lx2_train, ly2_train)
print('Waights:', l2reg.coef_)
print('Bias:', l2reg.intercept_)
print('R-squared:', l2reg.score(lx2_train,ly2_train))
# Our model can explain 77% of the variation in the dependent variable around its mean
# Out:
# Waights: [-4.41990997e-02  5.47033566e-02  3.12152193e-02 -2.89261847e-04
#   4.56260879e-01 -1.56619958e-02  6.58833541e-04  1.40821360e-03
#  -1.28345823e-01]
# Bias: 4.682124381384254
# R-squared: 0.7767686771937883

# %%
# Adjusted R-squared of the model
def adj_r2(x,y):
    r2 = l2reg.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2
print('Adjusted R-squared:', adj_r2(lx2_train,ly2_train))
# It seems the differance between R-squared and adjusted R-squared is very low.
# No inputs have been penalized
# Out:
# Adjusted R-squared: 0.7747144012170439

# %%
ly2_hat = l2reg.predict(lx2_train)

plt.axline((0.1, 0.1), slope=1, color='red', label='45 Degree')
plt.scatter(ly2_train, ly2_hat,alpha=0.2)
plt.xlabel('Targets(ly2_train)', size = 16)
plt.ylabel('Predictions(ly2_hat)', size = 16)
plt.xlim(7,14)
plt.ylim(7,14)
plt.legend()
plt.show()

# %%
# Another useful check of our model is a residual plot
# We can plot the PDF of the residuals and check for anomalies
sns.displot(ly2_train - ly2_hat, kde=True)
sns.set_style('darkgrid')
# Include a title
plt.title("Residuals PDF", size=18)

# In the best case scenario this plot should be normally distributed
# In our case we notice that there are some positive residuals (far away from the mean)
# Given the definition of the residuals (ly2_train - ly2_hat), positive values imply
# that y2_hat (predictions) are much lower than y2_train (the targets)
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %%
# testing
ly2_hat_test = l2reg.predict(lx2_test)


plt.axline((0.1, 0.1), slope=1, color='red', label='45 Degree')
plt.scatter(ly2_test, ly2_hat_test,alpha=0.2)
plt.xlabel('Targets(ly2_train)', size = 16)
plt.ylabel('Predictions(ly2_hat_test)', size = 16)
plt.xlim(7,14)
plt.ylim(7,14)
plt.legend()
plt.show()

# %%
sns.displot(ly2_test - ly2_hat_test, kde=True)
sns.set_style('darkgrid')
# Include a title
plt.title("Residuals PDF", size=18)
# Same as model, there are some positive residuals (far away from the mean)
# Given the definition of the residuals (ly2_test - ly2_hat_test), positive values imply
# that ly2_hat (predictions) are much lower than ly2_train (the targets)

# Our model can predict better in lower to medium priced phone than higher ones
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %%
# Let's manually check these predictions
# To obtain the actual prices, we take the exponential of the log_price
df_pf = pd.DataFrame(np.exp(ly2_hat_test), columns=['Predictions'])

# To get a proper result, we must reset the index and drop the old indexing
ly2_test = ly2_test.reset_index(drop=True)

# Again, we need the exponential of the test log price
df_pf['Target'] = np.exp(ly2_test)
df_pf
# Out:
#      Predictions   Target
# 0        9895.93 11450.00
# 1       29833.61 18990.00
# 2       27892.24 24499.00
# 3       51129.39 52652.00
# 4       17628.16 12490.00
# ..           ...      ...
# 243     14283.26 13999.00
# 244     20069.15 13990.00
# 245     19928.33 14990.00
# 246     19135.81 20500.00
# 247     27981.25 30799.00
#
# [248 rows x 2 columns]

# %%
# Additionally, we can calculate the difference between the targets and the predictions
# this is actually the residual (we already plotted the residuals)
df_pf['Residual'] = df_pf['Target'] - df_pf['Predictions']

# Finally, it makes sense to see how far off we are from the result percentage-wise
# Here, we take the absolute difference in %, so we can easily order the data frame
df_pf['Difference%'] = np.absolute(df_pf['Residual']/df_pf['Target']*100)
df_pf
# Out:
#      Predictions   Target  Residual  Difference%
# 0        9895.93 11450.00   1554.07        13.57
# 1       29833.61 18990.00 -10843.61        57.10
# 2       27892.24 24499.00  -3393.24        13.85
# 3       51129.39 52652.00   1522.61         2.89
# 4       17628.16 12490.00  -5138.16        41.14
# ..           ...      ...       ...          ...
# 243     14283.26 13999.00   -284.26         2.03
# 244     20069.15 13990.00  -6079.15        43.45
# 245     19928.33 14990.00  -4938.33        32.94
# 246     19135.81 20500.00   1364.19         6.65
# 247     27981.25 30799.00   2817.75         9.15
#
# [248 rows x 4 columns]

# %%
# Exploring the descriptives here gives us additional insights
df_pf.describe()
# Out:
#        Predictions    Target   Residual  Difference%
# count       248.00    248.00     248.00       248.00
# mean      32620.66  35162.12    2541.46        29.43
# std       26672.62  29347.24   19332.70        24.01
# min        5266.52   6999.00 -151034.45         0.03
# 25%       15432.47  13990.00   -5486.10        11.16
# 50%       27936.75  26489.00    -291.02        24.63
# 75%       42427.60  44999.00    6592.75        43.30
# max      271024.45 164999.00   73355.15       130.29

# %%
# Sometimes it is useful to check these outputs manually
# To see all rows, we use the relevant pandas syntax
pd.options.display.max_rows = 999
# Moreover, to make the dataset clear, we can display the result with only 2 digits after the dot 
pd.set_option('display.float_format', lambda x: '%.2f' % x)
# Finally, we sort by difference in % and manually check the model
df_pf.sort_values(by=['Difference%'])
# Out:
#      Predictions    Target   Residual  Difference%
# 151     19995.53  19990.00      -5.53         0.03
# 170     30012.97  29999.00     -13.97         0.05
# 63      41927.38  41990.00      62.62         0.15
# 106     38056.93  37999.00     -57.93         0.15
# 163     10457.01  10499.00      41.99         0.40
# 229     40194.90  39990.00    -204.90         0.51
# 11      55279.09  54990.00    -289.09         0.53
# 123      9930.83   9990.00      59.17         0.59
# 126     17108.70  16999.00    -109.70         0.65
# 212     20859.53  20999.00     139.47         0.66
# 234     24184.84  23990.00    -194.84         0.81
# 239      7430.05   7499.00      68.95         0.92
# 224     13114.40  12990.00    -124.40         0.96
# 93      12466.98  12332.00    -134.98         1.09
# 100     34597.60  34990.00     392.40         1.12
# 204     39513.18  39999.00     485.82         1.21
# 65      11211.34  10999.00    -212.34         1.93
# ...
